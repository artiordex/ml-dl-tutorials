# %% [markdown]
# # bike sharing demand (regression)

# %%
import xgboost as xgb ## XGBoost 불러오기
from xgboost import plot_importance ## Feature Importance를 불러오기 위함
from sklearn import datasets
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
train  = pd.read_csv('train.csv', index_col=['datetime'], parse_dates=['datetime'])
test  = pd.read_csv('test.csv', index_col=['datetime'], parse_dates=['datetime'])

# %%
train.head()
# Out:
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#                      humidity  windspeed  casual  registered  count
# datetime
# 2011-01-01 00:00:00        81        0.0       3          13     16
# 2011-01-01 01:00:00        80        0.0       8          32     40
# 2011-01-01 02:00:00        80        0.0       5          27     32
# 2011-01-01 03:00:00        75        0.0       3          10     13
# 2011-01-01 04:00:00        75        0.0       0           1      1

# %%
train.tail()
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2012-12-19 19:00:00       4        0           1        1  15.58  19.695
# 2012-12-19 20:00:00       4        0           1        1  14.76  17.425
# 2012-12-19 21:00:00       4        0           1        1  13.94  15.910
# 2012-12-19 22:00:00       4        0           1        1  13.94  17.425
# 2012-12-19 23:00:00       4        0           1        1  13.12  16.665
#
#                      humidity  windspeed  casual  registered  count
# datetime
# 2012-12-19 19:00:00        50    26.0027       7         329    336
# 2012-12-19 20:00:00        57    15.0013      10         231    241
# 2012-12-19 21:00:00        61    15.0013       4         164    168
# 2012-12-19 22:00:00        61     6.0032      12         117    129
# 2012-12-19 23:00:00        66     8.9981       4          84     88

# %%
test.head()
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#                      humidity  windspeed
# datetime
# 2011-01-20 00:00:00        56    26.0027
# 2011-01-20 01:00:00        56     0.0000
# 2011-01-20 02:00:00        56     0.0000
# 2011-01-20 03:00:00        56    11.0014
# 2011-01-20 04:00:00        56    11.0014

# %%
test.tail()
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2012-12-31 19:00:00       1        0           1        2  10.66  12.880
# 2012-12-31 20:00:00       1        0           1        2  10.66  12.880
# 2012-12-31 21:00:00       1        0           1        1  10.66  12.880
# 2012-12-31 22:00:00       1        0           1        1  10.66  13.635
# 2012-12-31 23:00:00       1        0           1        1  10.66  13.635
#
#                      humidity  windspeed
# datetime
# 2012-12-31 19:00:00        60    11.0014
# 2012-12-31 20:00:00        60    11.0014
# 2012-12-31 21:00:00        60    11.0014
# 2012-12-31 22:00:00        56     8.9981
# 2012-12-31 23:00:00        65     8.9981

# %%
train.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# std        8.474601     19.245033      8.164537     49.960477    151.039033
# min        0.760000      0.000000      0.000000      0.000000      0.000000
# 25%       16.665000     47.000000      7.001500      4.000000     36.000000
# 50%       24.240000     62.000000     12.998000     17.000000    118.000000
# 75%       31.060000     77.000000     16.997900     49.000000    222.000000
# max       45.455000    100.000000     56.996900    367.000000    886.000000
#
#               count
# count  10886.000000
# mean     191.574132
# std      181.144454
# min        1.000000
# 25%       42.000000
# 50%      145.000000
# 75%      284.000000
# max      977.000000

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10886 entries, 2011-01-01 00:00:00 to 2012-12-19 23:00:00
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      10886 non-null  int64
#  1   holiday     10886 non-null  int64
#  2   workingday  10886 non-null  int64
#  3   weather     10886 non-null  int64
#  4   temp        10886 non-null  float64
#  5   atemp       10886 non-null  float64
#  6   humidity    10886 non-null  int64
#  7   windspeed   10886 non-null  float64
#  8   casual      10886 non-null  int64
#  9   registered  10886 non-null  int64
#  10  count       10886 non-null  int64
# dtypes: float64(3), int64(8)
# memory usage: 1020.6 KB

# %%
train.plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
X_test = test[['season','holiday', 'workingday', 'weather', 
               'temp', 'atemp', 'humidity', 'windspeed']].values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 X_data = train[['season','holiday', 'workingday', 'weather',
#       2                'temp', 'atemp', 'humidity', 'windspeed']].values
#       3 y_data = train[['count']].values
#
# NameError: name 'train' is not defined

# %%
import numpy as np
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X_data, y_data, test_size=0.2) # train과 test를 8:2로 분할

# %%
model = xgb.XGBRegressor(n_estimators=100, learning_rate=0.08, gamma=0, subsample=0.75,
                           colsample_bytree=1, max_depth=7)

# %%
model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None, colsample_bytree=1,
#              device=None, early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, feature_weights=None,
#              gamma=0, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.08, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, ...)

# %%
y = model.predict(X_train)

# %%
print(model.score(X_train, y_train))
# Out:
# 0.5671849250793457

# %%
print(model.score(X_val, y_val))
# Out:
# 0.33814018964767456

# %%
train_score = []
val_score = []
n_range = range(80, 100)

for n in n_range:
    model = xgb.XGBRegressor(n_estimators=n, learning_rate=0.08, gamma=0, subsample=0.75,
                           colsample_bytree=1, max_depth=10)
    model.fit(X_train, y_train)
    train_score.append(model.score(X_train, y_train))
    val_score.append(model.score(X_val, y_val))

plt.figure()
plt.plot(n_range, train_score, label='train')
plt.plot(n_range, val_score, label='validation')
plt.legend()
plt.xlabel('n_estimators')
plt.ylabel('score')
plt.show()

# %%
from xgboost import plot_importance
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(5, 6))
plot_importance(model, ax=ax)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='Importance score', ylabel='Features'>

# %%
X_test = test[['season','holiday', 'workingday', 'weather', 
               'temp', 'atemp', 'humidity', 'windspeed']].values

# %%
y_pred = model.predict(X_test)

# %%
print(y_pred)
# Out:
# [117.91153   37.126488  37.126488 ...  84.50703   73.88666   45.726788]

# %%
test['count'] = y_pred

# %%
test.head()
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#                      humidity  windspeed       count
# datetime
# 2011-01-20 00:00:00        56    26.0027  117.911530
# 2011-01-20 01:00:00        56     0.0000   37.126488
# 2011-01-20 02:00:00        56     0.0000   37.126488
# 2011-01-20 03:00:00        56    11.0014   88.396523
# 2011-01-20 04:00:00        56    11.0014   88.396523

# %%
save_df = test.drop(columns=['season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed'])

# %%
save_df.head()
# Out:
#                           count
# datetime
# 2011-01-20 00:00:00  117.911530
# 2011-01-20 01:00:00   37.126488
# 2011-01-20 02:00:00   37.126488
# 2011-01-20 03:00:00   88.396523
# 2011-01-20 04:00:00   88.396523

# %%
save_df['count'] = save_df['count'].astype(int)

# %%
save_df.head()
# Out:
#                      count
# datetime
# 2011-01-20 00:00:00    117
# 2011-01-20 01:00:00     37
# 2011-01-20 02:00:00     37
# 2011-01-20 03:00:00     88
# 2011-01-20 04:00:00     88

# %%
save_df.to_csv('submission.csv', sep=',')

# %%
from sklearn import metrics

y_pred = model.predict(X_val)
print('mean_absolute_error: ', metrics.mean_absolute_error(y_val, y_pred)) # best는 0.0
print('mean_squared_error: ', metrics.mean_squared_error(y_val, y_pred)) # best는 0.0
print(f'MAPE: ', metrics.mean_absolute_percentage_error(y_val, y_pred) * 100) # best는 0.0%
print('r2_score: ', metrics.r2_score(y_val, y_pred)) # best는 1.0
# Out:
# mean_absolute_error:  108.7863998413086
# mean_squared_error:  23540.84765625
# MAPE:  357.8073501586914
# r2_score:  0.30246502161026
