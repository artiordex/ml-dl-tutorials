# %% [markdown]
# # penguins

# %%
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
import os
import random
import numpy as np

def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
#    torch.manual_seed(seed)
#    torch.cuda.manual_seed(seed)
#    torch.backends.cudnn.deterministic = True
#    torch.backends.cudnn.benchmark = False

seed_everything(42)

# %%
df = sns.load_dataset('penguins')

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
df.tail()
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 339  Gentoo  Biscoe             NaN            NaN                NaN
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male

# %%
print(df.shape)
# Out:
# (344, 7)

# %%
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
print(df.species.unique())
print(df.island.unique())
print(df.sex.unique())
# Out:
# ['Adelie' 'Chinstrap' 'Gentoo']
# ['Torgersen' 'Biscoe' 'Dream']
# ['Male' 'Female']

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

dfi = df.copy()

dfi['species'] = label_encoder.fit_transform(dfi['species'])
print(label_encoder.classes_)
dfi['island'] = label_encoder.fit_transform(dfi['island'])
print(label_encoder.classes_)
dfi['sex'] = label_encoder.fit_transform(dfi['sex'])
print(label_encoder.classes_)
# Out:
# ['Adelie' 'Chinstrap' 'Gentoo']
# ['Biscoe' 'Dream' 'Torgersen']
# ['Female' 'Male']

# %%
dfi.head()
# Out:
#    species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0        0       2            39.1           18.7              181.0
# 1        0       2            39.5           17.4              186.0
# 2        0       2            40.3           18.0              195.0
# 4        0       2            36.7           19.3              193.0
# 5        0       2            39.3           20.6              190.0
#
#    body_mass_g  sex
# 0       3750.0    1
# 1       3800.0    0
# 2       3250.0    0
# 4       3450.0    0
# 5       3650.0    1

# %%
y_data = dfi[['species']].values
dfi.drop('species', axis=1, inplace=True)
X_data = dfi.values

# %%
import numpy as np
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.2) # train과 test를 8:2로 분할

# %%
# !pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xgboost in /home/ubuntu/.local/lib/python3.10/site-packages (3.0.4)
# Requirement already satisfied: numpy in /home/ubuntu/.local/lib/python3.10/site-packages (from xgboost) (2.2.6)
# Requirement already satisfied: scipy in /home/ubuntu/.local/lib/python3.10/site-packages (from xgboost) (1.15.3)
# Requirement already satisfied: nvidia-nccl-cu12 in /home/ubuntu/.local/lib/python3.10/site-packages (from xgboost) (2.27.7)

# %%
import xgboost as xgb ## XGBoost 불러오기
from xgboost import plot_importance ## Feature Importance를 불러오기 위함

# %%
model = xgb.XGBClassifier(n_estimators=100, learning_rate=0.08, gamma=0, subsample=0.75,
                           colsample_bytree=1, max_depth=7)

# %%
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None, colsample_bytree=1,
#               device=None, early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, feature_weights=None,
#               gamma=0, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.08, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
y = model.predict(X_train)

# %%
print(y.shape)
print(y_train.shape)
# Out:
# (266,)
# (266, 1)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d, Axes3D 

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_train[:,0], X_train[:,1], X_train[:,2], c = y_train.reshape(-1))
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d, Axes3D 

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_train[:,0], X_train[:,1], X_train[:,2], c = y)
plt.show()

# %%
print(model.score(X_train, y_train))
# Out:
# 1.0

# %%
print(model.score(X_test, y_test))
# Out:
# 1.0

# %%
train_score = []
test_score = []
n_range = range(10, 20)

for n in n_range:
    model = xgb.XGBClassifier(n_estimators=n, learning_rate=0.08, gamma=0, subsample=0.75,
                           colsample_bytree=1, max_depth=10)
    model.fit(X_train, y_train)
    train_score.append(model.score(X_train, y_train))
    test_score.append(model.score(X_test, y_test))

plt.figure()
plt.plot(n_range, train_score, label='train')
plt.plot(n_range, test_score, label='test')
plt.legend()
plt.xlabel('max_depth')
plt.ylabel('score')
plt.show()

# %%
from sklearn import metrics

y_pred = model.predict(X_test)
print('accuarcy_score: ', metrics.accuracy_score(y_test, y_pred))
print('balanced_accuarcy_score: ', metrics.balanced_accuracy_score(y_test, y_pred))
print('classification_report: ', metrics.classification_report(y_test,y_pred))

r = metrics.classification_report(y_test,y_pred, output_dict=True)
print(r)
# Out:
# accuarcy_score:  1.0
# balanced_accuarcy_score:  1.0
# classification_report:                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        31
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        23
#
#     accuracy                           1.00        67
#    macro avg       1.00      1.00      1.00        67
# weighted avg       1.00      1.00      1.00        67
#
# {'0': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 31.0}, '1': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 13.0}, '2': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 23.0}, 'accuracy': 1.0, 'macro avg': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 67.0}, 'weighted avg': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 67.0}}
