# %% [markdown]
# # titanic

# %%
# %pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in c:\users\shiverlog\appdata\roaming\python\python313\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\shiverlog\appdata\roaming\python\python313\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\shiverlog\appdata\roaming\python\python313\site-packages (from seaborn) (2.3.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\shiverlog\appdata\roaming\python\python313\site-packages (from seaborn) (3.10.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shiverlog\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\shiverlog\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shiverlog\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\shiverlog\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\shiverlog\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\shiverlog\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\shiverlog\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shiverlog\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shiverlog\appdata\roaming\python\python313\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\shiverlog\appdata\roaming\python\python313\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\shiverlog\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# Seaborn에 내장된 Titanic 데이터셋 로드
# 승객 정보(성별, 나이, 객실 등)로 생존 여부를 예측하는 분류 문제에 사용됨
df = sns.load_dataset('titanic')

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.head() # 문자열은 통상 categorical data
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
print(df.shape)
# Out:
# (891, 15)

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# 결측값(NaN)이 포함된 행을 모두 제거
df.dropna(inplace=True)

# %%
# 결측치 확인
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 182 entries, 1 to 889
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     182 non-null    int64
#  1   pclass       182 non-null    int64
#  2   sex          182 non-null    object
#  3   age          182 non-null    float64
#  4   sibsp        182 non-null    int64
#  5   parch        182 non-null    int64
#  6   fare         182 non-null    float64
#  7   embarked     182 non-null    object
#  8   class        182 non-null    category
#  9   who          182 non-null    object
#  10  adult_male   182 non-null    bool
#  11  deck         182 non-null    category
#  12  embark_town  182 non-null    object
#  13  alive        182 non-null    object
#  14  alone        182 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 18.2+ KB

# %%
sns.pairplot(df)

# %%
# 성별(sex) 그룹별 생존율(survived)의 평균을 barplot으로 시각화
# estimator=mean 이 기본값이므로 생략해도 자동으로 평균을 계산해 막대를 그림
sns.barplot(x='sex', y='survived', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
sns.barplot(x='sex', y='fare', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
import pandas as pd

def agg_func(col):
    if pd.api.types.is_categorical_dtype(col) or pd.api.types.is_object_dtype(col):
        return 'count'
    elif pd.api.types.is_numeric_dtype(col):
        return 'mean'
    else:
        return 'first'

# 'sex' 열을 제외한 나머지 열에 대해서만 집계를 수행
columns_to_agg = [col for col in df.columns if col != 'sex']

groupedvalues = df.groupby('sex').agg({col: agg_func(df[col]) for col in columns_to_agg}).reset_index()
groupedvalues.head()
# Out:
# C:\Users\Shiverlog\AppData\Local\Temp\ipykernel_37208\2659779695.py:4: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(col) or pd.api.types.is_object_dtype(col):
#       sex  survived    pclass        age     sibsp     parch       fare  \
# 0  female  0.931818  1.215909  32.676136  0.534091  0.545455  89.000900
# 1    male  0.436170  1.170213  38.382128  0.404255  0.414894  69.482049
#
#    embarked  class  who  adult_male  deck  embark_town  alive     alone
# 0        88     88   88    0.000000    88           88     88  0.363636
# 1        94     94   94    0.925532    94           94     94  0.489362

# %%
g = sns.barplot(x='sex',y='survived',data=groupedvalues)

for index, row in groupedvalues.iterrows():
#    print(row.name, row.survived)
    g.text(row.name, row.survived, round(row.survived, 2), color='black', ha="center") # x, y, 텍스트

# %%
sns.barplot(x='sex', y='survived', hue = 'class', data=df) # hue를 설정한다. hue도 categorial value가 되어야 한다.
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
sns.barplot(x='sex', y='survived', hue = 'class', order = ['male', 'female'], data=df) # x축의 순서 설정
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
sns.barplot(x='sex', y='survived', hue = 'class', order = ['female', 'male'], estimator = sum, data=df) # estimator(함수) 변경
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
sns.barplot(x='sex', y='survived', hue = 'class', order = ['female', 'male'], palette="Blues_d", data=df) # 팔레트 변경
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
sns.barplot(x = 'sex', y = 'survived', hue = 'class', data = df).set(xlabel='Gender', ylabel='Survival Rate') # x, y축 텍스트 변경
# Out:
# [Text(0.5, 0, 'Gender'), Text(0, 0.5, 'Survival Rate')]

# %%
sns.barplot(x = 'sex', y = 'survived', hue = 'class', data = df).set_title("Gender vs Survival Rate in Males and Females") # 타이틀 변경
# Out:
# Text(0.5, 1.0, 'Gender vs Survival Rate in Males and Females')

# %%
sns.catplot(x="sex", y="survived", hue="class", col="alone", data=df, kind="bar") 
# categorial FacetGrid를 그린다. hue와 class는 서로 교체할 수 있다.

# %%
sns.catplot(x ="sex", hue ="survived", kind ="count", data = df)

# %%
group = df.groupby(['pclass', 'survived']) # 등급별 생존별 데이터 그룹화
#print(group.size())
#print(group.size().unstack())
pclass_survived = group.size().unstack()  # 그룹별 카운트(NA가 아닌 것)을 세고 pivot한다
sns.heatmap(pclass_survived, annot = True, fmt='d') # 히트맵을 그리고 데이터를 정수로 표기한다
# Out:
# <Axes: xlabel='survived', ylabel='pclass'>

# %%
sns.violinplot(x ="sex", y ="age", hue ="survived", data = df, split = True) # hue를 설정하고 분포 그래프를 그린다
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.violinplot(x ="sex", y ="age", hue ="survived", data = df, split = True, cut=0) 
female = df[df["sex"]=="female"]
male = df[df["sex"]=="male"]
print("female age, min: {}, max: {}".format(female["age"].min(), female["age"].max()))
print("male age, min: {}, max: {}".format(male["age"].min(), male["age"].max()))
# Out:
# female age, min: 2.0, max: 63.0
# male age, min: 0.92, max: 80.0

# %%
sns.catplot(x ='embarked', hue ='survived', kind ='count', col ='pclass', data = df) # categorical FacetGrid를 그린다.

# %%
df.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1          1       1  female  38.0      1      0  71.2833        C  First
# 3          1       1  female  35.0      1      0  53.1000        S  First
# 6          0       1    male  54.0      0      0  51.8625        S  First
# 10         1       3  female   4.0      1      1  16.7000        S  Third
# 11         1       1  female  58.0      0      0  26.5500        S  First
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 3   woman       False    C  Southampton   yes  False
# 6     man        True    E  Southampton    no   True
# 10  child       False    G  Southampton   yes  False
# 11  woman       False    C  Southampton   yes   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 182 entries, 1 to 889
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     182 non-null    int64
#  1   pclass       182 non-null    int64
#  2   sex          182 non-null    object
#  3   age          182 non-null    float64
#  4   sibsp        182 non-null    int64
#  5   parch        182 non-null    int64
#  6   fare         182 non-null    float64
#  7   embarked     182 non-null    object
#  8   class        182 non-null    category
#  9   who          182 non-null    object
#  10  adult_male   182 non-null    bool
#  11  deck         182 non-null    category
#  12  embark_town  182 non-null    object
#  13  alive        182 non-null    object
#  14  alone        182 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 18.2+ KB

# %%
print(df.sex.unique())
print(df.embarked.unique())
print(df['class'].unique())
print(df.who.unique())
print(df.deck.unique())
print(df.embark_town.unique())
print(df.alive.unique())
# Out:
# ['female' 'male']
# ['C' 'S' 'Q']
# ['First', 'Third', 'Second']
# Categories (3, object): ['First', 'Second', 'Third']
# ['woman' 'man' 'child']
# ['C', 'E', 'G', 'D', 'A', 'B', 'F']
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']
# ['Cherbourg' 'Southampton' 'Queenstown']
# ['yes' 'no']

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

dfi = df.copy()

dfi['sex'] = label_encoder.fit_transform(dfi['sex'])
print(label_encoder.classes_)
dfi['embarked'] = label_encoder.fit_transform(dfi['embarked'])
print(label_encoder.classes_)
dfi['class'] = label_encoder.fit_transform(dfi['class'])
print(label_encoder.classes_)
dfi['who'] = label_encoder.fit_transform(dfi['who'])
print(label_encoder.classes_)
dfi['deck'] = label_encoder.fit_transform(dfi['deck'])
print(label_encoder.classes_)
dfi['embark_town'] = label_encoder.fit_transform(dfi['embark_town'])
print(label_encoder.classes_)
dfi['alive'] = label_encoder.fit_transform(dfi['alive'])
print(label_encoder.classes_)
dfi['adult_male'] = label_encoder.fit_transform(dfi['adult_male'])
print(label_encoder.classes_)
dfi['alone'] = label_encoder.fit_transform(dfi['alone'])
print(label_encoder.classes_)
# Out:
# ['female' 'male']
# ['C' 'Q' 'S']
# ['First' 'Second' 'Third']
# ['child' 'man' 'woman']
# ['A' 'B' 'C' 'D' 'E' 'F' 'G']
# ['Cherbourg' 'Queenstown' 'Southampton']
# ['no' 'yes']
# [False  True]
# [False  True]

# %%
dfi.head()
# Out:
#     survived  pclass  sex   age  sibsp  parch     fare  embarked  class  who  \
# 1          1       1    0  38.0      1      0  71.2833         0      0    2
# 3          1       1    0  35.0      1      0  53.1000         2      0    2
# 6          0       1    1  54.0      0      0  51.8625         2      0    1
# 10         1       3    0   4.0      1      1  16.7000         2      2    0
# 11         1       1    0  58.0      0      0  26.5500         2      0    2
#
#     adult_male  deck  embark_town  alive  alone
# 1            0     2            0      1      0
# 3            0     2            2      1      0
# 6            1     4            2      0      1
# 10           0     6            2      1      0
# 11           0     2            2      1      1

# %%
#dfx = pd.concat([dfi['sex'], dfi['survived'], dfi['class'], dfi['age']], axis=1)
dfx = dfi[['sex', 'survived', 'class', 'age']]
sns.pairplot(dfx)
